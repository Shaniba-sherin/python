# %%
class student:
    name="Rahul"
    age=22

# %%
x=student()

# %%
x.name
# Out:
# 'Rahul'

# %%
x.age
# Out:
# 22

# %%
class car:
    brand="Toyota"
    model="Innova"

# %%
c=car

# %%
print("Brand:",c.brand)
print("model:",c.model)
# Out:
# Brand: Toyota
# model: Innova

# %%
class employee:
    def __init__(self,name,department,salary):
        self.name=name
        self.department=department
        self.salary=salary

# %%
e=employee("Anu","IT",30000)

# %%
print("name:",e.name)
print("department:",e.department)
print("salary:",e.salary)
# Out:
# name: Anu
# department: IT
# salary: 30000

# %%
class bankaccount:
    def __init__(self,account_holder,balance):
        self.account_holder=account_holder
        self.balance=balance

    def display_details(self):
        print(f"Account holder:{self.account_holder}") 
        print(f"balance:{self.balance}\n")

# %%
a1=bankaccount("arun",25000)
a2=bankaccount("rahul",40000)
a3=bankaccount("neha",35000)

# %%
a1.display_details()
# Out:
# Account holder:arun
# balance:25000

# %%
a2.display_details()
# Out:
# Account holder:rahul
# balance:40000

# %%
a3.display_details()
# Out:
# Account holder:neha
# balance:35000

# %%
class rectangle:
    def __init__(self,length,width):
        self.length=length
        self.width=width
    def area(self):
        return self.length*self.width  
    rect=rectangle(10,5) 
    print(f"area{rect.area()}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 class rectangle:
#       2     def __init__(self,length,width):
#       3         self.length=length
#       4         self.width=width
#
# Cell In[11], line 8, in rectangle()
#       4         self.width=width
#       5     def area(self):
#       6         return self.length*self.width
#       7     rect=rectangle(10,5)
# ----> 8     print(f"area{rect.area()}")
#
# Cell In[7], line 6, in rectangle.area(self)
#       5     def area(self):
# ----> 6         return self.length*width
#
# NameError: name 'width' is not defined

# %%
try:
    a=int(input("enter the nominator"))
    b=int(input("enter the denominator"))
    c=a/b

except ZeroDivisionError:
    print("cannot divide by zero")
# Out:
# cannot divide by zero

# %%
try:
    a=int(input("enter a number"))
    print(a)
except ValueError:
    print("invalid input! please enter a number")
# Out:
# invalid input! please enter a number

# %%
try:
    a=int(input("enter numerator"))
    b=int(input("enter denominator"))
    c=a/b
except ZeroDivisionError:
    print("cannot divide by zero")
except ValueError:
    print("enter a number")
# Out:
# cannot divide by zero

# %%
try:
    numbers=[10,20,30,40,50]
    index=int("enter the index position")
except:
    print("invalid index")
# Out:
# invalid index

# %%
try:
    age=int(input("enter the age"))
    if age<=18:
    print("you must be 18 or older")
except:
    print("you are eligible")
# Out:
#   Cell In[31], line 4
#     print("you must be 18 or older")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 3
