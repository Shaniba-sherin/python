# %%
#sortting
numbers=[45,12,78,3,29,56,8]
numbers.sort(key=lambda x:x)

# %%
numbers
# Out:
# [3, 8, 12, 29, 45, 56, 78]

# %%
words=["python","ai","machine","data","learning","ml"]
words.sort(key=lambda x:x)

# %%
words
# Out:
# ['ai', 'data', 'learning', 'machine', 'ml', 'python']
