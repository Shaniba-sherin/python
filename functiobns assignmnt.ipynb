# %%
a=int(input("enter the number"))
print("the number is even") if a%2==0 else print("the number is odd")
# Out:
# the number is odd

# %%
a=int(input("enter the first number"))
b=int(input("enter the second number"))
print("a is greater") if a>b else print("b is greater")
# Out:
# b is greater

# %%
mark=int(input("enter the mark"))
print("passed") if mark>=40 else print("failed")
# Out:
# failed

# %%
a=int(input("enter the number"))
print("the number is positive") if a>0 else print("the number is negative")
# Out:
# the number is negative

# %%
PA=4500
if PA>=5000:
    print("eligible for discount")
else:
    print("not eligible for discount")
# Out:
# not eligible for discount

# %%
day=6
match day:
    case 1:
        print("monday")
    case 2:
        print("tuesday")
    case 3:
        print("wednesday")
    case 4:
        print("thursday")
    case 5:
        print("friday")
    case 6:
        print("saturday")
    case 7:
        print("sunday")
    case _:
        print("invalid")
# Out:
# saturday

# %%
a=int(input("enter the number"))
b=int(input("enter the number"))
operator=(input("enter the operator(+,-,*,/)"))
match operator:
    case "+":
        print(a+b)
    case "-":
        print(a-b) 
    case "*":
        print(a*b)
    case "/":
        print(a/b)
    case _:
        print("invalid input")
# Out:
# 13

# %%
mark=int(input("enter the mark"))
match mark:
    case 1 if mark>90 and mark<=100:
        print("a grade")
    case 2 if mark>80 and mark<=90:
        print("b grade")
    case 3 if mark>70 and mark<=80:
        print("c grade")
    case 4 if mark>60 and mark<=70:
        print("d grade")
    case 5 if mark <=60:
        print("failed")

# %%
color="red"
match color:
    case "red":
        print("stop the vehicle")
    case "yellow":
        print("be ready to go")  
    case "green":
        print("go")
# Out:
# stop the vehicle

# %%
def avg(m1,m2,m3,m4,m5):
    print((m1+m2+m3+m4+m5)/5)

# %%
avg(m1=92, m2=89, m3=78, m4=85, m5=90)
if avg >50:
    print("passed")
else:
    print("failed")
# Out:
# 86.8
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 avg(m1=92, m2=89, m3=78, m4=85, m5=90)
# ----> 2 if avg >50:
#       3     print("passed")
#       4 else:
#       5     print("failed")
#
# TypeError: '>' not supported between instances of 'function' and 'int'

# %%
def check(**numbers):
    print(check)

# %%
check(n1=2,n2=3,n3=4,n4=5,n5=6)
# Out:
# <function check at 0x000002582725B5E0>
